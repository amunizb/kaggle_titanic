# %%
import sys
# !{sys.executable} -m pip install graphviz

# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# Getting the data
df_train = pd.read_csv("./data/train.csv")
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Preparing the data
df_train = df_train.dropna()

y_train = df_train["Survived"]

X_train = df_train.drop("Survived", axis=1)

irrelevant_features = ["PassengerId","Name","Ticket"]
problematic_features = ["Fare"]

X_train = X_train.drop(irrelevant_features+problematic_features, axis=1)
X_train = pd.get_dummies(X_train)

# %%
# Train random forest
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Get test data
df_test = pd.read_csv("./data/test.csv")
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Prepare test data

df_test = df_test.dropna()

#y_test = df_test["Survived"]

#X_test = df_test.drop("Survived", axis=1)

irrelevant_features = ["PassengerId","Name","Ticket"]
problematic_features = ["Fare"]

X_test = df.drop(irrelevant_features+problematic_features, axis=1)
X_test = pd.get_dummies(X_test)

# %%
# Predict and output predictions
predictions = rf.predict(X_test)

output = pd.DataFrame({"PassengerId": X_test.PassengerId, "prediction": predictions})
output.to_csv("output.csv", index=False)
print("Your submission was successfully saved!")
# Out:
# /Users/alvaromunizbrea/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Survived
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 2>()
#       1 # Predict and output predictions
# ----> 2 predictions = rf.predict(X_test)
#       4 output = pd.DataFrame({"PassengerId": X_test.PassengerId, "prediction": predictions})
#       5 output.to_csv("output.csv", index=False)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:832, in ForestClassifier.predict(self, X)
#     811 def predict(self, X):
#     812     """
#     813     Predict class for X.
#     814
#    (...)
# ...
